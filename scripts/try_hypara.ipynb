# %%
import os, sys
sys.path.insert(1, os.path.abspath('..'))
from hypara.spaces import space, prod, join, Operator, pprint
from hypara.domains import N,R

# %%
sp = space
op = Operator
a = space(R[1:5])
g = space([N, R])

# %%
d = space({
    'lambda' : R,
    'gamma' : N[0:],
})

# %%
space(R)
# Out:
# 'Continuous'(<hypara.domains.Intervall object at 0x7f192c4e1b38>)

# %%
js = a | d
js[1]['gamma']
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-5-903ef9147e56> in <module>()
# ----> 1 js = a | d
#       2 js[1]['gamma']
#
# /net/home/student/m/mmeier/code/statistician/hypara/spaces.py in __or__(self, arg)
#      51
#      52     def __or__(self, arg):
# ---> 53         return join(self, arg)
#      54
#      55     def __add__(self, arg):
#
# /net/home/student/m/mmeier/code/statistician/hypara/spaces.py in join(*args)
#     366         domain = set(args)
#     367     else:
# --> 368         domain = _spacify(args)
#     369     return JoinedSpace(domain)
#     370
#
# /net/home/student/m/mmeier/code/statistician/hypara/spaces.py in _spacify(domain)
#     243     """
#     244
# --> 245     log.debug('_spacify:' + str(domain))
#     246
#     247     if isinstance(domain, Space):
#
# /net/home/student/m/mmeier/code/statistician/hypara/spaces.py in __repr__(self)
#      47         return '%s(%s)' % (
#      48             repr(self.__class__.__name__),
# ---> 49             repr(self.domain)
#      50         )
#      51
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# ...
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# /net/home/student/m/mmeier/code/statistician/hypara/domains.py in __repr__(self)
#     101
#     102     def __repr__(self):
# --> 103         return 'Product(%s)' % repr(self)[1:-1]
#     104
#     105
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
print(d)

# %%
print(js.domain,'\n')
print(js,'\n')
pprint(js)

# %%
op1 = Operator(lambda a,b,c : a+b*c, 'dings')
op2 = Operator(lambda a : a**2, 'quad')

p = sp({
    op1(a=N[:10], b=N[:10], c=N[:10]),
    op2(N[:10]),
    op1(1),
})

# %%
c = op1(1)

# %%
type(c.domain[0])

# %%
prod([1,2,3],s=4)

# %%
pprint(p)

# %%
print(p)

# %%
p

# %%
a = space(
    {'a': 1,
     'b' : 2
    }
)

# %%
a

# %%
(1,2) + (3,4)

# %%
p

# %%
c

# %%
c.domain.args
